# %%
import pandas as pd

# %%
csv_files = ["/content/drive/MyDrive/ColabNotebooks/Final2/rotten_tomatoes_scarped_movies.csv", "/content/drive/MyDrive/ColabNotebooks/Final2/rotten_tomatoes_scarped_movies1001_1500.csv", "/content/drive/MyDrive/ColabNotebooks/Final2/rotten_tomatoes_scarped_movies1500_2000.csv", "/content/drive/MyDrive/ColabNotebooks/Final2/rotten_tomatoes_scarped_movies2000.csv", "/content/drive/MyDrive/ColabNotebooks/Final2/rotten_tomatoes_scarped_movies3000_3499.csv", "/content/drive/MyDrive/ColabNotebooks/Final2/rotten_tomatoes_scarped_movies3500_4000.csv"]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
d1 = pd.read_csv(csv_files[0])
d2 = pd.read_csv(csv_files[1])
d3 = pd.read_csv(csv_files[2])
d4 = pd.read_csv(csv_files[3])
d5 = pd.read_csv(csv_files[4])
d6 = pd.read_csv(csv_files[5])

frames = [d1,d2,d3,d4,d5,d6]
m = []
for df in frames:
    for _, row in df.iterrows():
        m.append(list(row))

# %%
df = pd.DataFrame(m)
df = df.drop_duplicates()

# %%
df.to_csv("comb_rtdata3.csv", index=False)
